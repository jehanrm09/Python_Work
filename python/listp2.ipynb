# %%
x=""
l=[]
for i in range(10):
    x=int(input("enter marks"))
    l.append(x)
l.sort()
print(l)
print("first max no: ",l[-1])
print("second max no: ",l[-2])
print("first min no: ",l[0])
print("second min no: ",l[1])
# Out:
# enter marks10
# enter marks20
# enter marks30
# enter marks40
# enter marks50
# enter marks60
# enter marks23
# enter marks25
# enter marks26
# enter marks32
# [10, 20, 23, 25, 26, 30, 32, 40, 50, 60]
# first max no:  60
# second max no:  50
# first min no:  10
# second min no:  20

# %%
for i in l:
    if i%2==0:
        print("even numbers: ",i)
for i in l:
    if i%2!=0:
        print("odd numbers: ",i)
# Out:
# even numbers:  10
# even numbers:  20
# even numbers:  26
# even numbers:  30
# even numbers:  32
# even numbers:  40
# even numbers:  50
# even numbers:  60
# odd numbers:  23
# odd numbers:  25

# %%
ans1=ans2=0
for i in l:
    if i%2==0:
        ans1=ans1+i
print("sum of even number:",ans1)
for i in l:
    if i%2!=0:
        ans2=ans2+i
print("sum of even number:",ans2)
# Out:
# sum of even number: 268
# sum of even number: 48

# %%
ev=[]
od=[]
for i in l:
    if i%2==0:
        ev.append(i)
print("sum of even number:",ev)
for i in l:
    if i%2!=0:
        od.append(i)
print("sum of even number:",ans2)
