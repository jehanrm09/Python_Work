# %%
x=[12,3,546,34,67]
x.reverse()
print(x)
x.append(10)
print(x)
# Out:
# [67, 34, 546, 3, 12]
# [67, 34, 546, 3, 12, 10]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a506d675b755> in <module>
#       4 x.append(10)
#       5 print(x)
# ----> 6 print(x.find(3))
#
# AttributeError: 'list' object has no attribute 'find'
