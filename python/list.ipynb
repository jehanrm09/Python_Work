# %%
x=[12,3,546,34,67]
y=[1,20,50,12,45,23]
x.reverse()
print(x)
x.append(10)
print(x)
print(max(x))
y.extend(x)
print(x)
print(x.sort())
x.insert(2,91)
print(x)
del x[0]
print(x)
x.remove(546)
x.pop(1)
print(x)
f=list(range(1,10))
print(f)
# Out:
# [67, 34, 546, 3, 12]
# [67, 34, 546, 3, 12, 10]
# 546
# [67, 34, 546, 3, 12, 10]
# None
# [3, 10, 91, 12, 34, 67, 546]
# [10, 91, 12, 34, 67, 546]
# [10, 12, 34, 67]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
