# %%
x=eval(input("enter elements"))
y=eval(input("enter elements"))
print(x+y)
print(type(x))
print(x)
print(sorted(x))
print(min(x))
print(max(x))
# Out:
# enter elements12,78,34,34
# enter elements32,54,65,78
# (12, 78, 34, 34, 32, 54, 65, 78)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-dd4ceb7e849e> in <module>
#       2 y=eval(input("enter elements"))
#       3 print(x+y)
# ----> 4 print(x.y)
#       5 print(type(x))
#       6 print(x)
#
# AttributeError: 'tuple' object has no attribute 'y'

# %%
x=(1,2,3)
y=(4,)
x+y
# Out:
# (1, 2, 3, 4)

# %%
x*2
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
sorted(x,reverse=True)
# Out:
# [3, 2, 1]

# %%
x=(10,30,450,386,45,30,78)
y=int(input("enter position :"))
z=x[0:(y-1):]+x[y::]
print(z)
# Out:
# enter position :3
# (10, 30, 386, 45, 30, 78)

# %%
x=(10,30,450,386,45,30,78)
y=eval(input("enter number"))
z=int(input("enter position"))
f=x[0:(z-1):]+y+x[z::]
print(f)
# Out:
# enter number12,
# enter position3
# (10, 30, 12, 386, 45, 30, 78)

# %%
x=(10,30,450,386,45,30,78)
y=eval(input("enter number"))
z=int(input("enter position"))
f=x[0:(z-1):]+y+x[(z+10)::]
print(f)
