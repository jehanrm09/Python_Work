# %%
a={1,2,3}
b={1,2,3,7,8}
print(a.issubset(b))
print(b.issuperset(a))
print(a.symmetric_difference(b))
print(a.difference(b))
print(a.union(b))
print(a.intersection(b))
a=frozenset(a)
# Out:
# True
# True
# {7, 8}
# set()
# {1, 2, 3, 7, 8}
# {1, 2, 3}

# %%
x=[1,2,6,3,5]
s=set(x)
print(s)
# Out:
# {1, 2, 3, 5, 6}
