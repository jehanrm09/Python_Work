# %%
d={}
a=""
b=0
for i in range(1,5):
    a=input("enter player name")
    b=int(input("enter player score"))
    d[a]=b
print(d)
for i,j in d.items():
    print(f"{i} score {j}")
for i,j in d.items():
    if j==max(d.values())
    print(f"{i} max scores {j}")
for i,j in d.items():
    if j==min(d.values())
    print(f"{i} min scores {j}")
# Out:
# enter player namedhoni
# enter player score123
# enter player namevirat
# enter player score345
# enter player nameshar
# enter player score455
# {'dhoni': 123, 'virat': 345, 'shar': 455}
# dict_items([('dhoni', 123), ('virat', 345), ('shar', 455)])
