# %%
x= "happy new year"
print(x[1:10:-2])

# %%
print(x[::-1])
# Out:
# raey wen yppah

# %%
print(x[1::-1])
# Out:
# ah

# %%
print(x[:1:-1])
# Out:
# raey wen ypp

# %%
print(x[:-6:-1])
# Out:
# raey

# %%
print(x[:6:-1])
# Out:
# raey we
