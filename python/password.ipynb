# %%
x=input("enter password")
u=0
l=0
n=0
s=0
e=0
count=3
if len(x)>8:
    for i in x:
        if i.isupper():
            u+=1
        elif i.islower():
            l+=1
        elif i.isspace():
            s+=1
        elif i.isnumeric():
            n+=1
        else:
            e=e+1
    if(u>=1)and(l>=1)and(n>=1)and(s==0):
        print("valid")
else:
    print("invalid")
# Out:
# enter passwordAbcd@1234
# valid
