# %%
x={"name":"jehan","age":6, "height":12.63}
print(x)
x["name"]="jehan"
x["ae"]=78
print(x)
del x["age"]
print(x)
# Out:
# {'name': 'jehan', 'age': 6, 'height': 12.63}
# {'name': 'jehan', 'age': 6, 'height': 12.63, 'ae': 78}
# {'name': 'jehan', 'height': 12.63, 'ae': 78}

# %%
print(x.keys())
print(x.values())
print(x.items())
for i,j in x.items():
    print(i,j)
# Out:
# dict_keys(['name', 'height', 'ae'])
# dict_values(['jehan', 12.63, 78])
# dict_items([('name', 'jehan'), ('height', 12.63), ('ae', 78)])
# name jehan
# height 12.63
# ae 78
