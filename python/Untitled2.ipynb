# %%
x=int(input("enter number"))
y=str(x)
u=int(input("enter shift"))
print(y[u::]+y[0:u:])
# Out:
# enter number163343
# enter shift2
# 334316

# %%
x=input("enter number")
z=int(input("enter position you want to delete : "))
print(x[0:(z-1):] + x[z::])
# Out:
# enter numberhii hello
# enter position you want to delete4
# hiihello

# %%
x=input("enter string")
ans=0
count=0
for i in x:
      if i.isnumeric():
            ans=ans+int(i) 
            count=count+1
print(ans)
print(ans//count)
# Out:
# enter stringsdd213
# 6

# %%
x=input("enter string")
y=x.split(" ")
for i in y:
    print(y[0].upper()+y[1:-1:]+y[-1].upper())
# Out:
# enter stringhii helo bye
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-d71cc9b11c60> in <module>
#       2 y=x.split(" ")
#       3 for i in y:
# ----> 4     print(y[0].upper()+y[1:-1:]+y[-1].upper())
#
# TypeError: can only concatenate str (not "list") to str
