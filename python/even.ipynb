# %%
x=input("enter string")
y=x.split()
for i in y:
    if len(i)%2==0:
        print(i)
# Out:
# enter stringhii hello bywe jack
# bywe
# jack

# %%
x=input("enter string")
y=x.split()
for i in y:
    if len(i)%2!=0:
        print(i[::-1])
# Out:
# enter stringhii hello byee
# iih
# olleh

# %%
x=input("enter string")
y=x.split()
for i in y:
    if i[0]==i[-1]:
        print(i)
# Out:
# enter stringhiih hello bye
# hiih

# %%
x=input("enter string")
y=x.split()
z=0
for i in y:
    z=i.count("a")
# Out:
# enter stringhaha
# 2
