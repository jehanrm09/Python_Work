# %%
x="good morning"
d={}
for i in x:
    d[i]=x.count(i)
print(d)
# Out:
# {'g': 2, 'o': 3, 'd': 1, ' ': 1, 'm': 1, 'r': 1, 'n': 2, 'i': 1}

# %%
x="hi hello hi how"
f=x.split()
a={}
for i in f:
    a[i]=x.count(i)
print(a)
# Out:
# {'hi': 2, 'hello': 1, 'how': 1}
