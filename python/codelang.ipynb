# %%
x=input("Enter string: ")
key=int(input("entr key"))
x=x.upper()
s=""
ans="ABCDEFGHIJKLMNOPQRSTUVWXYZ"
for i in x:
    if i in ans:
        sol=(ans.find(i)+key)%26   
        s=s+ans[sol]
    
    else:
        s=s+i
print(s)
# Out:
# Enter string: jehan rm
# entr key3
# MHKDQ UP
