# %%
x=""
l=[]
for i in range(5):
    x=input("enter name")
    l.append(x)
print(l)
# Out:
# enter namejehan
# enter nameroy
# enter namejeba
# enter nameriya
# enter namefarhin
# ['jehan', 'roy', 'jeba', 'riya', 'farhin']

# %%
import copy
x=[[1,2,3],[4,5,6,],[7,8,9]]
l=copy.deepcopy(x)
print(l)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
