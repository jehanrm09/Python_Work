# %%
l=[10,121,37,86]
a=[]
s=""
for i in l:
    if i>10:
        s=str(i)
        if int(s[0])%2!=0:
            if int(s[-1])%2!=0:
                a.append(s)
print(a)
# Out:
# ['121', '37']

# %%
q=[1,2,4,6,7,2]
z=[]
for i in q:
    z.append(i)
    z.append(7)
z.pop()
print(z)
# Out:
# [1, 7, 2, 7, 4, 7, 6, 7, 7, 7, 2]

# %%
import copy
d=[1,12,10,121,37,86]
d.sort()
f=copy.deepcopy(d)
j=int(len(f))
print(j)
print(f)
w=[]
for i in j:
    w.append(f[-1])
    f.remove(f[-1])
    w.append(f[0])
    f.remove(f[0])
print(w)
# Out:
# 6
# [1, 10, 12, 37, 86, 121]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-844ec8afec5e> in <module>
#       7 print(f)
#       8 w=[]
# ----> 9 for i in j:
#      10     w.append(f[-1])
#      11     f.remove(f[-1])
#
# TypeError: 'int' object is not iterable
