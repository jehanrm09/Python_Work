# %%
x=str(input("enter string : "))
y=x[-1]+x[1:-1]+x[0]

if(x==y):
    print(x[0::2])
else:
    print(x[1::2])

# %%
x=str(input("enter string : "))
if(x==x[::-1]):
    print(x[0::2])
else:
    print(x[1::2])

# %%
x="hello hii bye"
print(x.count("h"))
print(x.title())
print(x.swapcase())
print(x.upper())
print(x.lower())
print(x.replace('h','&'))

# %%
x=(input("enter string : "))
print(x.count("a"))
if(x.count("a")%2==0):
    print(x.upper())
else:
    print(x.lower())

# %%
x=str(input("enter string : "))
y=x.split(" ")
print(y)

# %%
j=("sa","jk","js")
h="&".join(j)
print(h)
# Out:
# sa&jk&js

# %%
x=(input("enter string : "))
y=x.split(" ")
print(len(x))
print(len(y))

for i in  y:
    print(i[::-1])
# Out:
# enter string : hello hii bye
# 13
# 3
# olleh
# iih
# eyb
