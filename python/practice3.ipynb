# %%
d={"x":[10,21,25,22],"y":[25,15,17,18],"z":[10,15,20,25],"s":[15,5,7,20]}
ans=0
l=[]
for i in d.values():
    l.append(i)
for i in l:
    ans+=l[i]
print(ans)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4efc7ecbccfd> in <module>
#       5     l.append(i)
#       6 for i in l:
# ----> 7     ans+=l[i]
#       8 print(ans)
#
# TypeError: list indices must be integers or slices, not list
